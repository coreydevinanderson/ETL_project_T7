# %%
# Dependencies
import pandas as pd

# %%
housing_df = pd.read_csv("output_csv\output_housing_value_by_state.csv")

# %%
display(housing_df)
# Out:
#    State  Average Home Price
# 0     CA         567563.5833
# 1     TX         208699.6667
# 2     NY         271862.0833
# 3     FL         257649.0833
# 4     IL         210242.8333
# 5     PA         194551.4167
# 6     OH         150804.0000
# 7     MI         172127.1667
# 8     GA         203632.0833
# 9     NC         204960.7500
# 10    NJ         349843.6667
# 11    VA         285270.5000
# 12    WA         412988.0833
# 13    MA         434274.0000
# 14    IN         155086.9167
# 15    AZ         267167.6667
# 16    TN         184767.2500
# 17    MO         164080.5833
# 18    MD         323450.0833
# 19    WI         193552.5000
# 20    MN         261241.5000
# 21    CO         414845.3333
# 22    AL         142704.5000
# 23    SC         192229.3333
# 24    LA         170722.9167
# 25    KY         146302.3333
# 26    OR         365922.1667
# 27    OK         129732.2500
# 28    CT         275120.5833
# 29    IA         152071.5000
# 30    MS         125752.5000
# ...

# %%
col_list = housing_df.columns.to_list()
type(col_list)
# Out:
# list

# %%
col_list_lowered = [name.lower() for name in col_list]

# %%
print(col_list_lowered)
# Out:
# ['state', 'average home price']

# %%
new_cols = [item.replace(" ", "_") for item in col_list_lowered]

# %%
print(new_cols)
# Out:
# ['state', 'average_home_price']

# %%
housing_new_df = housing_df.rename(columns = {"State":"state", "Average Home Price":"average_home_price"})

# %%
display(housing_new_df)
# Out:
#    state  average_home_price
# 0     CA         567563.5833
# 1     TX         208699.6667
# 2     NY         271862.0833
# 3     FL         257649.0833
# 4     IL         210242.8333
# 5     PA         194551.4167
# 6     OH         150804.0000
# 7     MI         172127.1667
# 8     GA         203632.0833
# 9     NC         204960.7500
# 10    NJ         349843.6667
# 11    VA         285270.5000
# 12    WA         412988.0833
# 13    MA         434274.0000
# 14    IN         155086.9167
# 15    AZ         267167.6667
# 16    TN         184767.2500
# 17    MO         164080.5833
# 18    MD         323450.0833
# 19    WI         193552.5000
# 20    MN         261241.5000
# 21    CO         414845.3333
# 22    AL         142704.5000
# 23    SC         192229.3333
# 24    LA         170722.9167
# 25    KY         146302.3333
# 26    OR         365922.1667
# 27    OK         129732.2500
# 28    CT         275120.5833
# 29    IA         152071.5000
# 30    MS         125752.5000
# ...

# %%
housing_new_df.to_csv("output_csv/avg_housing_cost.csv", index = False)
